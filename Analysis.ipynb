# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Results.csv')

# %%
df
# Out:
#     name       high  hour                   ts
# 0   BYND  37.804901     9  2022-05-02 09:55:00
# 1   BYND  37.990002    10  2022-05-02 10:30:00
# 2   BYND  37.590000    11  2022-05-02 11:30:00
# 3   BYND  37.330002    12  2022-05-02 12:20:00
# 4   BYND  36.570000    13  2022-05-02 13:05:00
# ..   ...        ...   ...                  ...
# 75   TTD  60.979900    12  2022-05-02 12:20:00
# 76   TTD  59.939999    13  2022-05-02 13:00:00
# 77   TTD  59.939999    13  2022-05-02 13:10:00
# 78   TTD  60.279999    14  2022-05-02 14:50:00
# 79   TTD  62.119999    15  2022-05-02 15:55:00
#
# [80 rows x 4 columns]

# %%
dff=df.loc[df['hour']==9]
dff
# Out:
#     name        high  hour                   ts
# 0   BYND   37.804901     9  2022-05-02 09:55:00
# 7   DDOG  123.339996     9  2022-05-02 09:55:00
# 14    FB  210.729996     9  2022-05-02 09:55:00
# 21  MSFT  280.440002     9  2022-05-02 09:55:00
# 28  NFLX  198.600006     9  2022-05-02 09:55:00
# 35  OKTA  123.349998     9  2022-05-02 09:55:00
# 42  PINS   21.240000     9  2022-05-02 09:55:00
# 50  SHOP  451.000000     9  2022-05-02 09:40:00
# 57  SNAP   29.540001     9  2022-05-02 09:50:00
# 65    SQ  103.069901     9  2022-05-02 09:55:00
# 72   TTD   61.224998     9  2022-05-02 09:55:00

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=dff2.index,y='high',data=dff)
# Out:
# <AxesSubplot:xlabel='name', ylabel='high'>

# %%
df2=df.groupby(['name','hour']).max('high')
df2
# Out:
#                 high
# name hour
# BYND 9     37.804901
#      10    37.990002
#      11    37.590000
#      12    37.330002
#      13    36.570000
# ...              ...
# TTD  11    60.639999
#      12    60.979900
#      13    59.939999
#      14    60.279999
#      15    62.119999
#
# [77 rows x 1 columns]

# %%
plt.figure(figsize=(15,10))

sns.lineplot(y='high',x='hour',data=df2,hue='name')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='high'>

# %%
dfs=df.groupby('name').min('ts')

# %%
dfe=df.groupby('name').max('ts')

# %%
dfoc=pd.concat([dfs, dfe], axis=0)

# %%
dfoc
# Out:
#             high  hour
# name
# BYND   36.570000     9
# DDOG  118.309998     9
# FB    204.809998     9
# MSFT  280.204987     9
# NFLX  196.089996     9
# OKTA  121.695099     9
# PINS   21.219999     9
# SHOP  439.519897     9
# SNAP   28.969999     9
# SQ    102.370003     9
# TTD    59.939999     9
# BYND   38.330002    15
# DDOG  123.339996    15
# FB    211.880005    15
# MSFT  284.940002    15
# NFLX  200.214096    15
# OKTA  124.004997    15
# PINS   22.275000    15
# SHOP  454.140015    15
# SNAP   29.540001    15
# SQ    105.970001    15
# TTD    62.119999    15

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=dfoc.index,y='high',data=dfoc,hue='hour')
# Out:
# <AxesSubplot:xlabel='name', ylabel='high'>

# %%
dfa=df.groupby(['name','hour']).max('high')

# %%
dfa
# Out:
#                 high
# name hour
# BYND 9     37.804901
#      10    37.990002
#      11    37.590000
#      12    37.330002
#      13    36.570000
# ...              ...
# TTD  11    60.639999
#      12    60.979900
#      13    59.939999
#      14    60.279999
#      15    62.119999
#
# [77 rows x 1 columns]

# %%
dfa=dfa.groupby('name').mean('high')

# %%
dfa
# Out:
#             high
# name
# BYND   37.509272
# DDOG  120.444085
# FB    208.667143
# MSFT  281.707851
# NFLX  198.579099
# OKTA  122.836442
# PINS   21.485714
# SHOP  446.482130
# SNAP   29.311429
# SQ    103.474815
# TTD    60.933556

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=dfa.index,y='high',data=dfa)
# Out:
# <AxesSubplot:xlabel='name', ylabel='high'>
